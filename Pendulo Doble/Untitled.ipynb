# %%
datos2_1 = copy(datos_2)

for i in 1:length(datos2_1)
   if 10 < datos2_1[i] < 100
        datos2_1[i] = 0.5
    elseif datos2_1[i] > 100
        datos2_1[i] = 1
    else
        datos2_1[i] = 0
    end
end
heatmap(datos2_1)

# %%
heatmap(datos1_1.*(0.4).+datos2_1)

# %%
datos1_1 = copy(datos_1)


for i in 1:length(datos1_1)
    if datos1_1[i] > 10
        datos1_1[i] = 1.5
    elseif 0<datos1_1[i]<10
            datos1_1[i] = datos1_1[i]*(1/25)
        #else
    end
end

heatmap(datos1_1)

# %%
using Plots, DataFrames, CSV

datos1 = CSV.read("I_T_10_1.csv", DataFrame)

datos_1 = Matrix(datos1)
heatmap(datos_1*(1/10))

# %%
heatmap(datos2_1.*(1/50))#.+datos_1*(1/10), c=cgrad([:green, :red, :white]))

# %%
heatmap(datos1_1)

# %%
datos3  = CSV.read("I_prueba6.csv", DataFrame)
datos_2 = Matrix(datos3)
heatmap(datos_2)
